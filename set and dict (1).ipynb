# %% [markdown]
# # set

# %% [markdown]
# #### set is written with {}
# #### it can not be retrived using index
# #### it does not allow duplicate
# #### mutable = we can add or remove but without index

# %%
my_set={1,5,3,6,4,8,11.5,"abc","hi","hello"}
my_set
# Out:
# {1, 11.5, 3, 4, 5, 6, 8, 'abc', 'hello', 'hi'}

# %%
my_set[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26704/2063814584.py in <module>
# ----> 1 my_set[0]
#
# TypeError: 'set' object is not subscriptable

# %%
my_set[0]=12
my_set
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26704/3557327346.py in <module>
# ----> 1 my_set[0]=12
#       2 my_set
#
# TypeError: 'set' object does not support item assignment

# %%
my_set.remove(8)
my_set
# Out:
# {1, 11.5, 3, 4, 5, 6, 'abc', 'hello', 'hi'}

# %%
my_set.add(123)
my_set
# Out:
# {1, 11.5, 123, 3, 4, 5, 6, 'abc', 'hello', 'hi'}

# %% [markdown]
# # DICTIONARY

# %%
my_dict={"a":"first",1:"first","a":"fifth",5:17,7:"fifth"}
my_dict
# Out:
# {'a': 'fifth', 1: 'first', 5: 17, 7: 'fifth'}

# %%
my_dict["a"]
# Out:
# 'fifth'

# %%
my_dict["fifth"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26704/3969222209.py in <module>
# ----> 1 my_dict["fifth"]
#
# KeyError: 'fifth'

# %%
my_dict.update({2:7})
my_dict
# Out:
# {'a': 'fifth', 1: 'first', 5: 17, 7: 'fifth', 2: 7}

# %% [markdown]
# #### dictionary has key-value pair data stucture
# #### curly bracets
# #### key is unique
# #### values can be duplicated
