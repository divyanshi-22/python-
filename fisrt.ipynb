# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ### print your name

# %% [markdown]
# ### case sensitive language

# %% [markdown]
# ####lalalal

# %% [markdown]
# #####llilili

# %% [markdown]
# #f

# %% [markdown]
# # lwlwlw

# %% [markdown]
# ## must give space after hashtag

# %%
print("shortcut")
# Out:
# shortcut

# %% [markdown]
# ## delet tab = x/dd
# ## add tab above = a
# ## add tab below = b
# ## run comment (markdown)= m
# ## run code = shift+enter

# %% [markdown]
# # DATA TYPES

# %%
x=10
print(x)
# Out:
# 10

# %%
type(x)
# Out:
# int

# %%
y=True
type(y)
# Out:
# bool

# %% [markdown]
# ### t should be capital it can't be true

# %%
y=False
type(y)
# Out:
# bool

# %%
name="div"
type(name)
# Out:
# str

# %% [markdown]
# ### string should be in single or double inverted commas

# %% [markdown]
# # rules for naming of variable

# %% [markdown]
# #### 1.only alphabets,_,numbers are allowed
# #### 2.should not start with numbers
# #### 3.can't give space in between
# #### 4.case sensitive

# %%
name_list="rudra","divyanshi"
name_list
# Out:
# ('rudra', 'divyanshi')
