# %% [markdown]
# # DATA STRUCTURES

# %%
my_list=[1,3,4,5,6.7,6.9,"hi",True]
my_list
# Out:
# [1, 3, 4, 5, 6.7, 6.9, 'hi', True]

# %%
my_list[5]
# Out:
# 6.9

# %% [markdown]
# ##### retrivable

# %%
my_list[5]=100
my_list
# Out:
# [1, 3, 4, 5, 6.7, 100, 'hi', True]

# %% [markdown]
# ###### mutable

# %%
my_list[9]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_58204/1849084039.py in <module>
# ----> 1 my_list[9]
#
# IndexError: list index out of range

# %% [markdown]
# #### 1.list is heterogenous(allowing all data types)
# #### 2.index starts with 0
# #### 3.can access elements with index

# %%
my_tuple=1,3,4,5,6.7,6.9,"hi",True
my_tuple
# Out:
# (1, 3, 4, 5, 6.7, 6.9, 'hi', True)

# %% [markdown]
# ##### note: we can write it within or without parantheses

# %%
my_tuple[5]
# Out:
# 6.9

# %%
my_tuple[5]=34
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_58204/2756120681.py in <module>
# ----> 1 my_tuple[5]=34
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# #### NOTE: IT IS NOT MUTABLE
